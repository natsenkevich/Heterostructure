# %%
import numpy as np
import matplotlib.pyplot as plt
from gpaw.response.qeh import Heterostructure
from gpaw.response.qeh import interpolate_building_blocks


#interpolate_building_blocks(BBfiles=['WSe2'], BBmotherfile='MoS2')

thick_MoS2 = 6.21
thick_WSe2 = 6.718

d_MoS2_WSe2 = (thick_MoS2 + thick_WSe2) / 2
inter_mass = 0.244

HS = Heterostructure(structure=['H-MoS2', 'H-WSe2'],
                     d=[d_MoS2_WSe2],
                     qmax=None,
                     wmax=0,
                     d0=thick_WSe2)

hl_array = np.array([0., 0., 1., 0.])
el_array = np.array([1., 0., 0., 0.])


# Getting the interlayer exciton screened interaction on a real grid
r, W_r = HS.get_exciton_screened_potential_r(
    r_array=np.linspace(1e-1, 1000, 10000),
    e_distr=el_array,
    h_distr=hl_array,
    )

plt.plot(r, W_r, '-g')
plt.title(r'Screened Interaction Energy')
plt.xlabel(r'${\bf r}$ (Ang)', fontsize=20)
plt.ylabel(r'$W({\bf r})$ (Ha)', fontsize=20)
#plt.savefig('W_r.svg')
plt.show()

#np.save('',r)
np.save('W12_r',W_r)

# %%
ee, ev = HS.get_exciton_binding_energies(eff_mass=inter_mass,
                                         e_distr=el_array,
                                         h_distr=hl_array)

print('The interlayer exciton binding energy is:', -ee[0])
# Out:
# ('The interlayer exciton binding energy is:', (0.2804254855832539-0j))

# %%
import numpy as np
import matplotlib.pyplot as plt
from gpaw.response.qeh import Heterostructure
from gpaw.response.qeh import interpolate_building_blocks


#interpolate_building_blocks(BBfiles=['WSe2'], BBmotherfile='MoS2')

thick_MoS2 = 6.21
thick_WSe2 = 6.718

d_MoS2_WSe2 = (thick_MoS2 + thick_WSe2) / 2
inter_mass = 0.244

HS = Heterostructure(structure=['H-MoS2', 'H-WSe2'],
                     d=[d_MoS2_WSe2],
                     qmax=None,
                     wmax=0,
                     d0=thick_WSe2)

hl_array = np.array([1., 0., 0., 0.])
el_array = np.array([0., 0., 1., 0.])


# Getting the interlayer exciton screened interaction on a real grid
r, W_r = HS.get_exciton_screened_potential_r(
    r_array=np.linspace(1e-1, 1000, 10000),
    e_distr=el_array,
    h_distr=hl_array,
    )

plt.plot(r, W_r, '-g')
plt.title(r'Screened Interaction Energy')
plt.xlabel(r'${\bf r}$ (Ang)', fontsize=20)
plt.ylabel(r'$W({\bf r})$ (Ha)', fontsize=20)
#plt.savefig('W_r.svg')
plt.show()

np.save('rrr',r)
np.save('W21_r',W_r)

# %%
ee, ev = HS.get_exciton_binding_energies(eff_mass=inter_mass,
                                         e_distr=el_array,
                                         h_distr=hl_array)

print('The interlayer exciton binding energy is:', -ee[0])
# Out:
# ('The interlayer exciton binding energy is:', (0.2814279209165748-0j))

# %%
thick_MoS2 = 6.21
thick_WSe2 = 6.718

d_MoS2_WSe2 = (thick_MoS2 + thick_WSe2) / 2
inter_mass = 0.277

HS = Heterostructure(structure=['H-MoS2', 'H-WSe2'],
                     d=[d_MoS2_WSe2],
                     qmax=None,
                     wmax=0,
                     d0=thick_WSe2)

hl_array = np.array([1., 0., 0., 0.])
el_array = np.array([1., 0., 0., 0.])


# Getting the interlayer exciton screened interaction on a real grid
r, W_r = HS.get_exciton_screened_potential_r(
    r_array=np.linspace(1e-1, 1000, 10000),
    e_distr=el_array,
    h_distr=hl_array,
    )

plt.plot(r, W_r, '-g')
plt.title(r'Screened Interaction Energy')
plt.xlabel(r'${\bf r}$ (Ang)', fontsize=20)
plt.ylabel(r'$W({\bf r})$ (Ha)', fontsize=20)
#plt.savefig('W_r.svg')
plt.show()

#np.save('',r)
np.save('MoS2_W_r',W_r)

# %%
ee, ev = HS.get_exciton_binding_energies(eff_mass=inter_mass,
                                         e_distr=el_array,
                                         h_distr=hl_array)

print('The interlayer exciton binding energy is:', -ee[0].real)
# Out:
# ('The interlayer exciton binding energy is:', 0.41820350376855453)

# %%
thick_MoS2 = 6.21
thick_WSe2 = 6.718

d_MoS2_WSe2 = (thick_MoS2 + thick_WSe2) / 2
inter_mass = 0.23

HS = Heterostructure(structure=['H-MoS2', 'H-WSe2'],
                     d=[d_MoS2_WSe2],
                     qmax=None,
                     wmax=0,
                     d0=thick_WSe2)

hl_array = np.array([0., 0., 1., 0.])
el_array = np.array([0., 0., 1., 0.])


# Getting the interlayer exciton screened interaction on a real grid
r, W_r = HS.get_exciton_screened_potential_r(
    r_array=np.linspace(1e-1, 1000, 10000),
    e_distr=el_array,
    h_distr=hl_array,
    )

plt.plot(r, W_r, '-g')
plt.title(r'Screened Interaction Energy')
plt.xlabel(r'${\bf r}$ (Ang)', fontsize=20)
plt.ylabel(r'$W({\bf r})$ (Ha)', fontsize=20)
#plt.savefig('W_r.svg')
plt.show()

#np.save('',r)
np.save('WSe2_W_r',W_r)

# %%
ee, ev = HS.get_exciton_binding_energies(eff_mass=inter_mass,
                                         e_distr=el_array,
                                         h_distr=hl_array)

print('The interlayer exciton binding energy is:', -ee[0].real)
# Out:
# ('The interlayer exciton binding energy is:', 0.3852445210060802)
